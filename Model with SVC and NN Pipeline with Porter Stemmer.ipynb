# %% [markdown]
# ### Imports for this Notebook

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.model_selection import StratifiedShuffleSplit
from gensim.models.doc2vec import TaggedDocument
from gensim.models.doc2vec import Doc2Vec
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.neural_network import MLPClassifier, BernoulliRBM
import sklearn.metrics as metrics
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %% [markdown]
# ### Read data

# %%
# path to the train data file
INDATA_LOCATION = 'C:/Users/sharm/Desktop/Dat5Melb/Final_Project/Datasets/train/train.csv'

# utility definitions for easier handling of the dataset column names
TEXT_COLUMN = 'comment_text'
CLASS_TOXIC, CLASS_SEVER_TOXIC, CLASS_OBSCENE, CLASS_THREAT, CLASS_INSULT, \
    CLASS_IDENTITY_HATE = ["toxic", "severe_toxic", "obscene", "threat", \
                           "insult", "identity_hate"]
CLASSES = [CLASS_TOXIC, CLASS_SEVER_TOXIC, CLASS_OBSCENE, CLASS_THREAT, CLASS_INSULT, CLASS_IDENTITY_HATE]

def read_data(filename):
    return pd.read_csv(filename) 

# read the comments and associated classification data 
dataDf = read_data(INDATA_LOCATION)

# %%
cv = CountVectorizer(binary=False,
                     stop_words='english',
                     min_df=2)

docs = cv.fit_transform(dataDf['comment_text'])

# Build a mapping of numerical ID to word
id2word = dict(enumerate(cv.get_feature_names()))

# %%
id2word
# Out:
# {0: u'00',
#  1: u'000',
#  2: u'0000',
#  3: u'00000',
#  4: u'000000',
#  5: u'0000z',
#  6: u'0001',
#  7: u'0003',
#  8: u'000_bucks',
#  9: u'000ft',
#  10: u'000s',
#  11: u'000th',
#  12: u'001',
#  13: u'0015',
#  14: u'002',
#  15: u'003',
#  16: u'004',
#  17: u'0049703',
#  18: u'005',
#  19: u'006',
#  20: u'007',
#  21: u'008',
#  22: u'009',
#  23: u'00am',
#  24: u'00pm',
#  25: u'00utc',
#  26: u'01',
#  27: u'010',
#  28: u'0100',
#  29: u'0108',
#  30: u'011',
#  31: u'0110',
#  32: u'012',
#  33: u'013',
#  34: u'014',
#  35: u'016',
#  36: u'01w',
#  37: u'02',
#  38: u'0200',
#  39: u'0207',
#  40: u'0208hrs',
#  41: u'021',
#  42: u'023',
#  43: u'0230',
#  44: u'0231130104',
#  45: u'026',
#  46: u'027',
#  47: u'0287221',
#  48: u'03',
#  49: u'034',
#  50: u'039',
#  51: u'0393322521',
#  52: u'04',
#  53: u'040',
#  54: u'0400',
#  55: u'041',
#  56: u'0416',
#  57: u'0422',
#  58: u'0429hrs',
#  59: u'046',
#  60: u'048',
#  61: u'049',
#  62: u'0495',
#  63: u'05',
#  64: u'050',
#  65: u'051211',
#  66: u'053',
#  67: u'055',
#  68: u'0576',
#  69: u'058',
#  70: u'059',
#  71: u'05mm',
#  72: u'06',
#  73: u'0600z',
#  74: u'0612',
#  75: u'062',
#  76: u'064',
#  77: u'065',
#  78: u'067',
#  79: u'07',
#  80: u'070',
#  81: u'071',
#  82: u'0713990619',
#  83: u'073',
#  84: u'0730z',
#  85: u'075',
#  86: u'076',
#  87: u'07791',
#  88: u'08',
#  89: u'081',
#  90: u'082',
#  91: u'084080',
#  92: u'087',
#  93: u'087209',
#  94: u'089',
#  95: u'08t',
#  96: u'09',
#  97: u'090',
#  98: u'0918',
#  99: u'093',
#  100: u'095',
#  101: u'096',
#  102: u'098',
#  103: u'099',
#  104: u'0_o',
#  105: u'0cbsq6aewaa',
#  106: u'0cc8q6aewatgo',
#  107: u'0ccmq6aewaa',
#  108: u'0cdwq6aewazgk',
#  109: u'0ceoq6aewbg',
#  110: u'0em',
#  111: u'0f',
#  112: u'0k',
#  113: u'0m',
#  114: u'0n',
#  115: u'0px',
#  116: u'0q5pxmir2u',
#  117: u'0rr',
#  118: u'0waldo',
#  119: u'0wn',
#  120: u'0x',
#  121: u'0x00',
#  122: u'0x01',
#  123: u'0x0104',
#  124: u'0\xban',
#  125: u'0\xbas',
#  126: u'0\xbaw',
#  127: u'10',
#  128: u'100',
#  129: u'1000',
#  130: u'10000',
#  131: u'100000',
#  132: u'1000000',
#  133: u'100000000000000000',
#  134: u'1000americorps',
#  135: u'1000s',
#  136: u'1001',
#  137: u'1002',
#  138: u'1003',
#  139: u'1005',
#  140: u'1006',
#  141: u'1007',
#  142: u'1008',
#  143: u'1009',
#  144: u'100ft',
#  145: u'100k',
#  146: u'100kb',
#  147: u'100km',
#  148: u'100m',
#  149: u'100mg',
#  150: u'100million',
#  151: u'100px',
#  152: u'100s',
#  153: u'100th',
#  154: u'100x',
#  155: u'101',
#  156: u'1010',
#  157: u'1011',
#  158: u'1015',
#  159: u'1015380438_vcjcs',
#  160: u'1015392289_xmwsn',
#  161: u'1016',
#  162: u'1017',
#  163: u'101st',
#  164: u'102',
#  165: u'1020',
#  166: u'1021',
#  167: u'1024',
#  168: u'1024x768',
#  169: u'1025',
#  170: u'1028',
#  171: u'103',
#  172: u'1030',
#  173: u'1034',
#  174: u'1036',
#  175: u'104',
#  176: u'1040',
#  177: u'1042',
#  178: u'1046',
#  179: u'1047',
#  180: u'1048',
#  181: u'1049',
#  182: u'105',
#  183: u'1050',
#  184: u'1051',
#  185: u'1055',
#  186: u'1056',
#  187: u'105mm',
#  188: u'106',
#  189: u'1060',
#  190: u'1066',
#  191: u'107',
#  192: u'1074601',
#  193: u'1075',
#  194: u'108',
#  195: u'1080',
#  196: u'1080p',
#  197: u'109',
#  198: u'1091',
#  199: u'1099',
#  200: u'109g',
#  201: u'10a',
#  202: u'10am',
#  203: u'10c',
#  204: u'10k',
#  205: u'10km',
#  206: u'10m',
#  207: u'10mm',
#  208: u'10pm',
#  209: u'10px',
#  210: u'10s',
#  211: u'10th',
#  212: u'10x',
#  213: u'11',
#  214: u'110',
#  215: u'1100',
#  216: u'11000',
#  217: u'1100s',
#  218: u'1101',
#  219: u'1102',
#  220: u'110704',
#  221: u'110th',
#  222: u'111',
#  223: u'1110',
#  224: u'1111',
#  225: u'11111',
#  226: u'1112',
#  227: u'1117',
#  228: u'1118',
#  229: u'112',
#  230: u'112007',
#  231: u'1124',
#  232: u'112k',
#  233: u'112th',
#  234: u'113',
#  235: u'1133',
#  236: u'1135',
#  237: u'114',
#  238: u'1140',
#  239: u'1143',
#  240: u'1148022',
#  241: u'115',
#  242: u'1150',
#  243: u'1157',
#  244: u'1159',
#  245: u'116',
#  246: u'1160',
#  247: u'1165',
#  248: u'1166',
#  249: u'1167',
#  250: u'1168',
#  251: u'117',
#  252: u'1170',
#  253: u'1172',
#  254: u'1174',
#  255: u'1175',
#  256: u'1178',
#  257: u'1179',
#  258: u'117avenue',
#  259: u'118',
#  260: u'1181',
#  261: u'1185',
#  262: u'1189',
#  263: u'119',
#  264: u'1191',
#  265: u'1192',
#  266: u'11b',
#  267: u'11pm',
#  268: u'11th',
#  269: u'12',
#  270: u'120',
#  271: u'1200',
#  272: u'12000',
#  273: u'1200s',
#  274: u'1200z',
#  275: u'1202',
#  276: u'1204',
#  277: u'1205',
#  278: u'120px',
#  279: u'121',
#  280: u'1210',
#  281: u'1212625173',
#  282: u'1215',
#  283: u'1216',
#  284: u'1218',
#  285: u'122',
#  286: u'1228',
#  287: u'1229',
#  288: u'123',
#  289: u'1230',
#  290: u'1234',
#  291: u'12345',
#  292: u'123456',
#  293: u'1235',
#  294: u'1236',
#  295: u'124',
#  296: u'1240',
#  297: u'1241',
#  298: u'1244',
#  299: u'1249hrs',
#  300: u'125',
#  301: u'12500',
#  302: u'1258',
#  303: u'125http',
#  304: u'126',
#  305: u'1264745',
#  306: u'1265',
#  307: u'127',
#  308: u'1270',
#  309: u'1278',
#  310: u'1279',
#  311: u'128',
#  312: u'1280',
#  313: u'1280x1024',
#  314: u'1285',
#  315: u'1286',
#  316: u'128k',
#  317: u'129',
#  318: u'12951',
#  319: u'1297',
#  320: u'1298',
#  321: u'1299',
#  322: u'12pm',
#  323: u'12px',
#  324: u'12th',
#  325: u'13',
#  326: u'130',
#  327: u'1300',
#  328: u'13000',
#  329: u'13056306',
#  330: u'1309',
#  331: u'131',
#  332: u'1310',
#  333: u'1311',
#  334: u'1314',
#  335: u'132',
#  336: u'1320',
#  337: u'1321',
#  338: u'1322',
#  339: u'1323',
#  340: u'1326',
#  341: u'1328',
#  342: u'133',
#  343: u'13339',
#  344: u'1334',
#  345: u'1335',
#  346: u'1336',
#  347: u'1337',
#  348: u'134',
#  349: u'1347',
#  350: u'1348923',
#  351: u'135',
#  352: u'1350',
#  353: u'1351',
#  354: u'135291',
#  355: u'1355',
#  356: u'1356',
#  357: u'136',
#  358: u'1360',
#  359: u'1362',
#  360: u'136240411',
#  361: u'1365',
#  362: u'1366',
#  363: u'1368',
#  364: u'1369',
#  365: u'137',
#  366: u'138',
#  367: u'1380',
#  368: u'13843046_dmcc48',
#  369: u'1389',
#  370: u'139',
#  371: u'1390',
#  372: u'13909',
#  373: u'1397',
#  374: u'1399',
#  375: u'13k',
#  376: u'13th',
#  377: u'14',
#  378: u'140',
#  379: u'1400',
#  380: u'14000',
#  381: u'1400s',
#  382: u'1402',
#  383: u'1404',
#  384: u'141',
#  385: u'1415',
#  386: u'1416',
#  387: u'142',
#  388: u'1421',
#  389: u'1423151997',
#  390: u'1424',
#  391: u'1429',
#  392: u'143',
#  393: u'1430s',
#  394: u'1435',
#  395: u'143559040',
#  396: u'1439',
#  397: u'144',
#  398: u'1446',
#  399: u'145',
#  400: u'1450',
#  401: u'1453',
#  402: u'1455',
#  403: u'145th',
#  404: u'146',
#  405: u'14625',
#  406: u'1467',
#  407: u'147',
#  408: u'1472',
#  409: u'1476',
#  410: u'1477',
#  411: u'1478',
#  412: u'1479',
#  413: u'148',
#  414: u'1481',
#  415: u'1483',
#  416: u'1484',
#  417: u'1485',
#  418: u'1486',
#  419: u'1488',
#  420: u'149',
#  421: u'1490',
#  422: u'1492',
#  423: u'1493',
#  424: u'1494',
#  425: u'1497',
#  426: u'1498',
#  427: u'1499',
#  428: u'149th',
#  429: u'14c',
#  430: u'14d',
#  431: u'14pt',
#  432: u'14th',
#  433: u'14user',
#  434: u'15',
#  435: u'150',
#  436: u'1500',
#  437: u'15000',
#  438: u'1500s',
#  439: u'1501',
#  440: u'1503',
#  441: u'150348488',
#  442: u'1509',
#  443: u'150k',
#  444: u'150kb',
#  445: u'150px',
#  446: u'150th',
#  447: u'150x100px',
#  448: u'151',
#  449: u'1510',
#  450: u'1513',
#  451: u'1515',
#  452: u'1517',
#  453: u'1517519',
#  454: u'1518',
#  455: u'152',
#  456: u'1520',
#  457: u'1525',
#  458: u'1526',
#  459: u'153',
#  460: u'1530',
#  461: u'1532',
#  462: u'1534',
#  463: u'1536',
#  464: u'1538',
#  465: u'1539',
#  466: u'153rd',
#  467: u'154',
#  468: u'1541',
#  469: u'1542',
#  470: u'1543',
#  471: u'1546',
#  472: u'1547',
#  473: u'1547hrs',
#  474: u'1548',
#  475: u'155',
#  476: u'1555',
#  477: u'1556',
#  478: u'1557',
#  479: u'1558',
#  480: u'15585',
#  481: u'1559',
#  482: u'156',
#  483: u'1561',
#  484: u'1562',
#  485: u'1563',
#  486: u'1565',
#  487: u'1567',
#  488: u'1568',
#  489: u'157',
#  490: u'1577',
#  491: u'1578',
#  492: u'158',
#  493: u'1580',
#  494: u'1581',
#  495: u'1585',
#  496: u'1587',
#  497: u'159',
#  498: u'1592',
#  499: u'1593',
#  500: u'1595',
#  501: u'1597',
#  502: u'1599',
#  503: u'15am',
#  504: u'15k',
#  505: u'15pm',
#  506: u'15px',
#  507: u'15s',
#  508: u'15th',
#  509: u'16',
#  510: u'160',
#  511: u'1600',
#  512: u'16000',
#  513: u'1600s',
#  514: u'1601',
#  515: u'1603',
#  516: u'1604',
#  517: u'1605',
#  518: u'160k',
#  519: u'161',
#  520: u'1611',
#  521: u'1612',
#  522: u'1614202',
#  523: u'1615',
#  524: u'1618',
#  525: u'162',
#  526: u'1620',
#  527: u'1621',
#  528: u'1623',
#  529: u'1625',
#  530: u'1625097',
#  531: u'1626',
#  532: u'1629',
#  533: u'163',
#  534: u'1630',
#  535: u'1631',
#  536: u'1632',
#  537: u'1634',
#  538: u'1635',
#  539: u'1639',
#  540: u'164',
#  541: u'1640',
#  542: u'1641',
#  543: u'1643',
#  544: u'1646',
#  545: u'1647',
#  546: u'1649',
#  547: u'165',
#  548: u'1650',
#  549: u'1652',
#  550: u'1653',
#  551: u'1654',
#  552: u'1659',
#  553: u'166',
#  554: u'1660',
#  555: u'1662',
#  556: u'1663',
#  557: u'1664',
#  558: u'1666',
#  559: u'167',
#  560: u'1674',
#  561: u'168',
#  562: u'1683',
#  563: u'1685',
#  564: u'1688',
#  565: u'1689',
#  566: u'168th',
#  567: u'169',
#  568: u'1690',
#  569: u'1691',
#  570: u'1694',
#  571: u'1695',
#  572: u'16a',
#  573: u'16d',
#  574: u'16k',
#  575: u'16m',
#  576: u'16s',
#  577: u'16th',
#  578: u'17',
#  579: u'170',
#  580: u'1700',
#  581: u'1700s',
#  582: u'1704',
#  583: u'1705',
#  584: u'1706',
#  585: u'1707',
#  586: u'171',
#  587: u'1710',
#  588: u'1711',
#  589: u'1712',
#  590: u'1713',
#  591: u'1714',
#  592: u'1715',
#  593: u'1717',
#  594: u'1718',
#  595: u'1719',
#  596: u'172',
#  597: u'1720',
#  598: u'1722',
#  599: u'1723880',
#  600: u'1725',
#  601: u'1729',
#  602: u'173',
#  603: u'1732',
#  604: u'1733',
#  605: u'1733hrs',
#  606: u'1734',
#  607: u'1735',
#  608: u'1736',
#  609: u'174',
#  610: u'1741',
#  611: u'1742',
#  612: u'1743',
#  613: u'1745',
#  614: u'1747',
#  615: u'175',
#  616: u'1750',
#  617: u'1751',
#  618: u'1752',
#  619: u'1755',
#  620: u'1756',
#  621: u'1757',
#  622: u'1758',
#  623: u'1759',
#  624: u'176',
#  625: u'1760',
#  626: u'1761',
#  627: u'1762',
#  628: u'1763',
#  629: u'1764',
#  630: u'1765',
#  631: u'1766',
#  632: u'1767',
#  633: u'1768',
#  634: u'1769',
#  635: u'177',
#  636: u'1770',
#  637: u'1770s',
#  638: u'1771',
#  639: u'1773',
#  640: u'1774',
#  641: u'1775',
#  642: u'1776',
#  643: u'1777',
#  644: u'1778',
#  645: u'1779',
#  646: u'178',
#  647: u'1780',
#  648: u'178070',
#  649: u'1783',
#  650: u'178383952',
#  651: u'178429228',
#  652: u'1785',
#  653: u'1786',
#  654: u'1787',
#  655: u'1788',
#  656: u'1789',
#  657: u'179',
#  658: u'1790',
#  659: u'1790s',
#  660: u'1791',
#  661: u'1792',
#  662: u'1793',
#  663: u'1794',
#  664: u'1795',
#  665: u'1796',
#  666: u'1797',
#  667: u'1798',
#  668: u'1799',
#  669: u'17gb',
#  670: u'17s',
#  671: u'17th',
#  672: u'18',
#  673: u'180',
#  674: u'1800',
#  675: u'1800s',
#  676: u'1800z',
#  677: u'1801',
#  678: u'1802',
#  679: u'1803',
#  680: u'1804',
#  681: u'1805',
#  682: u'1806',
#  683: u'1807',
#  684: u'1808',
#  685: u'1809',
#  686: u'180px',
#  687: u'181',
#  688: u'1810',
#  689: u'1811',
#  690: u'1812',
#  691: u'1813',
#  692: u'1814',
#  693: u'1815',
#  694: u'1816',
#  695: u'1817',
#  696: u'1818',
#  697: u'1819',
#  698: u'182',
#  699: u'1820',
#  700: u'1820s',
#  701: u'1821',
#  702: u'1822',
#  703: u'1823',
#  704: u'1824',
#  705: u'1825',
#  706: u'1826',
#  707: u'1827',
#  708: u'1828',
#  709: u'1829',
#  710: u'183',
#  711: u'1830',
#  712: u'1830s',
#  713: u'1831',
#  714: u'1832',
#  715: u'1833',
#  716: u'1834',
#  717: u'1835',
#  718: u'1836',
#  719: u'1837',
#  720: u'1838',
#  721: u'1839',
#  722: u'184',
#  723: u'1840',
#  724: u'1840s',
#  725: u'1841',
#  726: u'1842',
#  727: u'1843',
#  728: u'1844',
#  729: u'1845',
#  730: u'1846',
#  731: u'1847',
#  732: u'1848',
#  733: u'1849',
#  734: u'185',
#  735: u'1850',
#  736: u'1850s',
#  737: u'1851',
#  738: u'1852',
#  739: u'1853',
#  740: u'1854',
#  741: u'1855',
#  742: u'1856',
#  743: u'1857',
#  744: u'1858',
#  745: u'1859',
#  746: u'1859842712',
#  747: u'186',
#  748: u'1860',
#  749: u'1860s',
#  750: u'1861',
#  751: u'1862',
#  752: u'1863',
#  753: u'1864',
#  754: u'1865',
#  755: u'1866',
#  756: u'1867',
#  757: u'1868',
#  758: u'1869',
#  759: u'187',
#  760: u'1870',
#  761: u'1870s',
#  762: u'1871',
#  763: u'1872',
#  764: u'1873',
#  765: u'1874',
#  766: u'1875',
#  767: u'1876',
#  768: u'1877',
#  769: u'1878',
#  770: u'1879',
#  771: u'188',
#  772: u'1880',
#  773: u'1880s',
#  774: u'1881',
#  775: u'1882',
#  776: u'1883',
#  777: u'188385',
#  778: u'1884',
#  779: u'1885',
#  780: u'1886',
#  781: u'1887',
#  782: u'1888',
#  783: u'1889',
#  784: u'189',
#  785: u'1890',
#  786: u'1890s',
#  787: u'1891',
#  788: u'1892',
#  789: u'1892848015',
#  790: u'1893',
#  791: u'1894',
#  792: u'1895',
#  793: u'1896',
#  794: u'1897',
#  795: u'1898',
#  796: u'1899',
#  797: u'18px',
#  798: u'18s',
#  799: u'18th',
#  800: u'19',
#  801: u'190',
#  802: u'1900',
#  803: u'19000',
#  804: u'1900s',
#  805: u'1901',
#  806: u'1902',
#  807: u'1903',
#  808: u'1904',
#  809: u'1904a',
#  810: u'1905',
#  811: u'1906',
#  812: u'1907',
#  813: u'1908',
#  814: u'1909',
#  815: u'191',
#  816: u'1910',
#  817: u'1910s',
#  818: u'1911',
#  819: u'1912',
#  820: u'1913',
#  821: u'1914',
#  822: u'1915',
#  823: u'1916',
#  824: u'1917',
#  825: u'1918',
#  826: u'1919',
#  827: u'192',
#  828: u'1920',
#  829: u'1920s',
#  830: u'1921',
#  831: u'1922',
#  832: u'1923',
#  833: u'1924',
#  834: u'1925',
#  835: u'1926',
#  836: u'1927',
#  837: u'1928',
#  838: u'1929',
#  839: u'193',
#  840: u'1930',
#  841: u'1930s',
#  842: u'1931',
#  843: u'1932',
#  844: u'1933',
#  845: u'1934',
#  846: u'1935',
#  847: u'1936',
#  848: u'1937',
#  849: u'1938',
#  850: u'1939',
#  851: u'194',
#  852: u'1940',
#  853: u'1940s',
#  854: u'1941',
#  855: u'1942',
#  856: u'1943',
#  857: u'1944',
#  858: u'1945',
#  859: u'1946',
#  860: u'1947',
#  861: u'1948',
#  862: u'1949',
#  863: u'195',
#  864: u'1950',
#  865: u'1950s',
#  866: u'1951',
#  867: u'19519379_itm',
#  868: u'1952',
#  869: u'1953',
#  870: u'1954',
#  871: u'1955',
#  872: u'1956',
#  873: u'1957',
#  874: u'1958',
#  875: u'1959',
#  876: u'196',
#  877: u'1960',
#  878: u'1960s',
#  879: u'1961',
#  880: u'1962',
#  881: u'1963',
#  882: u'1964',
#  883: u'1965',
#  884: u'1966',
#  885: u'1967',
#  886: u'1968',
#  887: u'196860',
#  888: u'1969',
#  889: u'197',
#  890: u'1970',
#  891: u'1970s',
#  892: u'1971',
#  893: u'1972',
#  894: u'1973',
#  895: u'1974',
#  896: u'1975',
#  897: u'1976',
#  898: u'1977',
#  899: u'1978',
#  900: u'1979',
#  901: u'198',
#  902: u'1980',
#  903: u'1980s',
#  904: u'1981',
#  905: u'1982',
#  906: u'1983',
#  907: u'1984',
#  908: u'1985',
#  909: u'198570352',
#  910: u'198582584',
#  911: u'1985_0216_greyhound_predatory_pricing',
#  912: u'1986',
#  913: u'1987',
#  914: u'1988',
#  915: u'1989',
#  916: u'199',
#  917: u'1990',
#  918: u'1990_0408_news',
#  919: u'1990s',
#  920: u'1990th',
#  921: u'1991',
#  922: u'1992',
#  923: u'1993',
#  924: u'1994',
#  925: u'1995',
#  926: u'1996',
#  927: u'1997',
#  928: u'1998',
#  929: u'1999',
#  930: u'1999a',
#  931: u'19b',
#  932: u'19c',
#  933: u'19th',
#  934: u'19xx',
#  935: u'1a',
#  936: u'1a4',
#  937: u'1acb',
#  938: u'1am',
#  939: u'1b',
#  940: u'1b0d',
#  941: u'1c',
#  942: u'1c1rnhn_enin478in478',
#  943: u'1ca8',
#  944: u'1d',
#  945: u'1e',
#  946: u'1em',
#  947: u'1er',
#  948: u'1k',
#  949: u'1km',
#  950: u'1m',
#  951: u'1mbbozu',
#  952: u'1pm',
#  953: u'1px',
#  954: u'1r',
#  955: u'1rr',
#  956: u'1rst',
#  957: u'1s',
#  958: u'1st',
#  959: u'1ugww',
#  960: u'1up',
#  961: u'1v1',
#  962: u'1xc5vpyn1eh6cwlmnujksofkgcrwjeq4amyptxphrqzg',
#  963: u'20',
#  964: u'200',
#  965: u'2000',
#  966: u'20000',
#  967: u'20006',
#  968: u'2000ad',
#  969: u'2000s',
#  970: u'2001',
#  971: u'2002',
#  972: u'2003',
#  973: u'2003041800080100',
#  974: u'2004',
#  975: u'2004a',
#  976: u'2005',
#  977: u'20051200210003144',
#  978: u'200512090016',
#  979: u'2005a',
#  980: u'2006',
#  981: u'2007',
#  982: u'2008',
#  983: u'2008_south_ossetia_war',
#  984: u'2008and',
#  985: u'2008georgia',
#  986: u'2009',
#  987: u'2009_ar',
#  988: u'2009of',
#  989: u'200er',
#  990: u'200k',
#  991: u'200kb',
#  992: u'200m',
#  993: u'200px',
#  994: u'200th',
#  995: u'201',
#  996: u'2010',
#  997: u'20100828013436',
#  998: u'2010digital',
#  999: u'2010s',
#  ...}

# %%
from gensim.models.ldamodel import LdaModel
from gensim.matutils import Sparse2Corpus

# First we convert our word-matrix into gensim's format
corpus = Sparse2Corpus(docs, documents_columns = False)

# Then we fit an LDA model
lda_model = LdaModel(corpus=corpus, id2word=id2word, num_topics=50)

# %%
num_topics = 6
num_words_per_topic = 3
for ti, topic in enumerate(lda_model.show_topics(num_topics = num_topics, num_words = num_words_per_topic)):
    print("Topic: %d" % (ti))
    print (topic)
    print()
# Out:
# Topic: 0
# (24, u'0.018*"al" + 0.017*"talking" + 0.017*"band"')
# ()
# Topic: 1
# (19, u'0.028*"000" + 0.024*"yes" + 0.020*"infobox"')
# ()
# Topic: 2
# (14, u'0.097*"hate" + 0.063*"suck" + 0.056*"game"')
# ()
# Topic: 3
# (42, u'0.076*"article" + 0.068*"deletion" + 0.042*"deleted"')
# ()
# Topic: 4
# (7, u'0.021*"white" + 0.018*"character" + 0.017*"song"')
# ()
# Topic: 5
# (33, u'0.055*"stupid" + 0.041*"wrong" + 0.032*"right"')
# ()

# %%
dataDf['comment_text'].str.lower()
# Out:
# 0         explanation\nwhy the edits made under my usern...
# 1         d'aww! he matches this background colour i'm s...
# 2         hey man, i'm really not trying to edit war. it...
# 3         "\nmore\ni can't make any real suggestions on ...
# 4         you, sir, are my hero. any chance you remember...
# 5         "\n\ncongratulations from me as well, use the ...
# 6              cocksucker before you piss around on my work
# 7         your vandalism to the matt shirvington article...
# 8         sorry if the word 'nonsense' was offensive to ...
# 9         alignment on this subject and which are contra...
# 10        "\nfair use rationale for image:wonju.jpg\n\nt...
# 11        bbq \n\nbe a man and lets discuss it-maybe ove...
# 12        hey... what is it..\n@ | talk .\nwhat is it......
# 13        before you start throwing accusations and warn...
# 14        oh, and the girl above started her arguments w...
# 15        "\n\njuelz santanas age\n\nin 2002, juelz sant...
# 16        bye! \n\ndon't look, come or think of comming ...
# 17         redirect talk:voydan pop georgiev- chernodrinski
# 18        the mitsurugi point made no sense - why not ar...
# 19        don't mean to bother you \n\ni see that you're...
# 20        "\n\n regarding your recent edits \n\nonce aga...
# 21        "\ngood to know. about me, yeah, i'm studying ...
# 22        "\n\n snowflakes are not always symmetrical! \...
# 23        "\n\n the signpost: 24 september 2012 \n\n rea...
# 24        "\n\nre-considering 1st paragraph edit?\ni don...
# 25        radial symmetry \n\nseveral now extinct lineag...
# 26        there's no need to apologize. a wikipedia arti...
# 27        yes, because the mother of the child in the ca...
# 28        "\nok. but it will take a bit of work but i ca...
# 29        "== a barnstar for you! ==\n\n  the real life ...
#                                 ...
# 159541    your absurd edits \n\nyour absurd edits on gre...
# 159542    maybe he's got better things to do than spend ...
# 159543    scrap that, it does meet criteria and its gone...
# 159544                                  you could do worse.
# 159545    , 7 march 2011 (utc)\nare you also user:bmatts...
# 159546    "\n\nhey listen don't you ever!!!! delete my e...
# 159547                       thank you very, very much.  ·✆
# 159548                          talkback: 15 september 2012
# 159549                           2005 (utc)\n 06:35, 31 mar
# 159550    i agree/ on another note lil wayne is a talent...
# 159551    while about half the references are from byu-i...
# 159552    prague spring \n\ni think that prague spring d...
# 159553    i see this as having been merged; undoing one ...
# 159554    and i'm going to keep posting the stuff u dele...
# 159555    "\n\nhow come when you download that mp3 it's ...
# 159556    i'll be on irc, too, if you have a more specif...
# 159557    it is my opinion that that happens to be off-t...
# 159558    please stop removing content from wikipedia; i...
# 159559    image:barack-obama-mother.jpg listed for delet...
# 159560    "editing of article without consensus & remova...
# 159561    "\nno he did not, read it again (i would have ...
# 159562    "\n auto guides and the motoring press are not...
# 159563    "\nplease identify what part of blp applies be...
# 159564    catalan independentism is the social movement ...
# 159565    the numbers in parentheses are the additional ...
# 159566    ":::::and for the second time of asking, when ...
# 159567    you should be ashamed of yourself \n\nthat is ...
# 159568    spitzer \n\numm, theres no actual article for ...
# 159569    and it looks like it was actually you who put ...
# 159570    "\nand ... i really don't think you understand...
# Name: comment_text, Length: 159571, dtype: object

# %%
import sys

class PorterStemmer:

    def __init__(self):
        """The main part of the stemming algorithm starts here.
        b is a buffer holding a word to be stemmed. The letters are in b[k0],
        b[k0+1] ... ending at b[k]. In fact k0 = 0 in this demo program. k is
        readjusted downwards as the stemming progresses. Zero termination is
        not in fact used in the algorithm.

        Note that only lower case sequences are stemmed. Forcing to lower case
        should be done before stem(...) is called.
        """

        self.b = ""  # buffer for word to be stemmed
        self.k = 0
        self.k0 = 0
        self.j = 0   # j is a general offset into the string

    def cons(self, i):
        """cons(i) is TRUE <=> b[i] is a consonant."""
        if self.b[i] == 'a' or self.b[i] == 'e' or self.b[i] == 'i' or self.b[i] == 'o' or self.b[i] == 'u':
            return 0
        if self.b[i] == 'y':
            if i == self.k0:
                return 1
            else:
                return (not self.cons(i - 1))
        return 1

    def m(self):
        """m() measures the number of consonant sequences between k0 and j.
        if c is a consonant sequence and v a vowel sequence, and <..>
        indicates arbitrary presence,

           <c><v>       gives 0
           <c>vc<v>     gives 1
           <c>vcvc<v>   gives 2
           <c>vcvcvc<v> gives 3
           ....
        """
        n = 0
        i = self.k0
        while 1:
            if i > self.j:
                return n
            if not self.cons(i):
                break
            i = i + 1
        i = i + 1
        while 1:
            while 1:
                if i > self.j:
                    return n
                if self.cons(i):
                    break
                i = i + 1
            i = i + 1
            n = n + 1
            while 1:
                if i > self.j:
                    return n
                if not self.cons(i):
                    break
                i = i + 1
            i = i + 1

    def vowelinstem(self):
        """vowelinstem() is TRUE <=> k0,...j contains a vowel"""
        for i in range(self.k0, self.j + 1):
            if not self.cons(i):
                return 1
        return 0

    def doublec(self, j):
        """doublec(j) is TRUE <=> j,(j-1) contain a double consonant."""
        if j < (self.k0 + 1):
            return 0
        if (self.b[j] != self.b[j-1]):
            return 0
        return self.cons(j)

    def cvc(self, i):
        """cvc(i) is TRUE <=> i-2,i-1,i has the form consonant - vowel - consonant
        and also if the second c is not w,x or y. this is used when trying to
        restore an e at the end of a short  e.g.

           cav(e), lov(e), hop(e), crim(e), but
           snow, box, tray.
        """
        if i < (self.k0 + 2) or not self.cons(i) or self.cons(i-1) or not self.cons(i-2):
            return 0
        ch = self.b[i]
        if ch == 'w' or ch == 'x' or ch == 'y':
            return 0
        return 1

    def ends(self, s):
        """ends(s) is TRUE <=> k0,...k ends with the string s."""
        length = len(s)
        if s[length - 1] != self.b[self.k]: # tiny speed-up
            return 0
        if length > (self.k - self.k0 + 1):
            return 0
        if self.b[self.k-length+1:self.k+1] != s:
            return 0
        self.j = self.k - length
        return 1

    def setto(self, s):
        """setto(s) sets (j+1),...k to the characters in the string s, readjusting k."""
        length = len(s)
        self.b = self.b[:self.j+1] + s + self.b[self.j+length+1:]
        self.k = self.j + length

    def r(self, s):
        """r(s) is used further down."""
        if self.m() > 0:
            self.setto(s)

    def step1ab(self):
        """step1ab() gets rid of plurals and -ed or -ing. e.g.

           caresses  ->  caress
           ponies    ->  poni
           ties      ->  ti
           caress    ->  caress
           cats      ->  cat

           feed      ->  feed
           agreed    ->  agree
           disabled  ->  disable

           matting   ->  mat
           mating    ->  mate
           meeting   ->  meet
           milling   ->  mill
           messing   ->  mess

           meetings  ->  meet
        """
        if self.b[self.k] == 's':
            if self.ends("sses"):
                self.k = self.k - 2
            elif self.ends("ies"):
                self.setto("i")
            elif self.b[self.k - 1] != 's':
                self.k = self.k - 1
        if self.ends("eed"):
            if self.m() > 0:
                self.k = self.k - 1
        elif (self.ends("ed") or self.ends("ing")) and self.vowelinstem():
            self.k = self.j
            if self.ends("at"):   self.setto("ate")
            elif self.ends("bl"): self.setto("ble")
            elif self.ends("iz"): self.setto("ize")
            elif self.doublec(self.k):
                self.k = self.k - 1
                ch = self.b[self.k]
                if ch == 'l' or ch == 's' or ch == 'z':
                    self.k = self.k + 1
            elif (self.m() == 1 and self.cvc(self.k)):
                self.setto("e")

    def step1c(self):
        """step1c() turns terminal y to i when there is another vowel in the stem."""
        if (self.ends("y") and self.vowelinstem()):
            self.b = self.b[:self.k] + 'i' + self.b[self.k+1:]

    def step2(self):
        """step2() maps double suffices to single ones.
        so -ization ( = -ize plus -ation) maps to -ize etc. note that the
        string before the suffix must give m() > 0.
        """
        if self.b[self.k - 1] == 'a':
            if self.ends("ational"):   self.r("ate")
            elif self.ends("tional"):  self.r("tion")
        elif self.b[self.k - 1] == 'c':
            if self.ends("enci"):      self.r("ence")
            elif self.ends("anci"):    self.r("ance")
        elif self.b[self.k - 1] == 'e':
            if self.ends("izer"):      self.r("ize")
        elif self.b[self.k - 1] == 'l':
            if self.ends("bli"):       self.r("ble") # --DEPARTURE--
            # To match the published algorithm, replace this phrase with
            #   if self.ends("abli"):      self.r("able")
            elif self.ends("alli"):    self.r("al")
            elif self.ends("entli"):   self.r("ent")
            elif self.ends("eli"):     self.r("e")
            elif self.ends("ousli"):   self.r("ous")
        elif self.b[self.k - 1] == 'o':
            if self.ends("ization"):   self.r("ize")
            elif self.ends("ation"):   self.r("ate")
            elif self.ends("ator"):    self.r("ate")
        elif self.b[self.k - 1] == 's':
            if self.ends("alism"):     self.r("al")
            elif self.ends("iveness"): self.r("ive")
            elif self.ends("fulness"): self.r("ful")
            elif self.ends("ousness"): self.r("ous")
        elif self.b[self.k - 1] == 't':
            if self.ends("aliti"):     self.r("al")
            elif self.ends("iviti"):   self.r("ive")
            elif self.ends("biliti"):  self.r("ble")
        elif self.b[self.k - 1] == 'g': # --DEPARTURE--
            if self.ends("logi"):      self.r("log")
        # To match the published algorithm, delete this phrase

    def step3(self):
        """step3() dels with -ic-, -full, -ness etc. similar strategy to step2."""
        if self.b[self.k] == 'e':
            if self.ends("icate"):     self.r("ic")
            elif self.ends("ative"):   self.r("")
            elif self.ends("alize"):   self.r("al")
        elif self.b[self.k] == 'i':
            if self.ends("iciti"):     self.r("ic")
        elif self.b[self.k] == 'l':
            if self.ends("ical"):      self.r("ic")
            elif self.ends("ful"):     self.r("")
        elif self.b[self.k] == 's':
            if self.ends("ness"):      self.r("")

    def step4(self):
        """step4() takes off -ant, -ence etc., in context <c>vcvc<v>."""
        if self.b[self.k - 1] == 'a':
            if self.ends("al"): pass
            else: return
        elif self.b[self.k - 1] == 'c':
            if self.ends("ance"): pass
            elif self.ends("ence"): pass
            else: return
        elif self.b[self.k - 1] == 'e':
            if self.ends("er"): pass
            else: return
        elif self.b[self.k - 1] == 'i':
            if self.ends("ic"): pass
            else: return
        elif self.b[self.k - 1] == 'l':
            if self.ends("able"): pass
            elif self.ends("ible"): pass
            else: return
        elif self.b[self.k - 1] == 'n':
            if self.ends("ant"): pass
            elif self.ends("ement"): pass
            elif self.ends("ment"): pass
            elif self.ends("ent"): pass
            else: return
        elif self.b[self.k - 1] == 'o':
            if self.ends("ion") and (self.b[self.j] == 's' or self.b[self.j] == 't'): pass
            elif self.ends("ou"): pass
            # takes care of -ous
            else: return
        elif self.b[self.k - 1] == 's':
            if self.ends("ism"): pass
            else: return
        elif self.b[self.k - 1] == 't':
            if self.ends("ate"): pass
            elif self.ends("iti"): pass
            else: return
        elif self.b[self.k - 1] == 'u':
            if self.ends("ous"): pass
            else: return
        elif self.b[self.k - 1] == 'v':
            if self.ends("ive"): pass
            else: return
        elif self.b[self.k - 1] == 'z':
            if self.ends("ize"): pass
            else: return
        else:
            return
        if self.m() > 1:
            self.k = self.j

    def step5(self):
        """step5() removes a final -e if m() > 1, and changes -ll to -l if
        m() > 1.
        """
        self.j = self.k
        if self.b[self.k] == 'e':
            a = self.m()
            if a > 1 or (a == 1 and not self.cvc(self.k-1)):
                self.k = self.k - 1
        if self.b[self.k] == 'l' and self.doublec(self.k) and self.m() > 1:
            self.k = self.k -1

    def stem(self, p, i, j):
        """In stem(p,i,j), p is a char pointer, and the string to be stemmed
        is from p[i] to p[j] inclusive. Typically i is zero and j is the
        offset to the last character of a string, (p[j+1] == '\0'). The
        stemmer adjusts the characters p[i] ... p[j] and returns the new
        end-point of the string, k. Stemming never increases word length, so
        i <= k <= j. To turn the stemmer into a module, declare 'stem' as
        extern, and delete the remainder of this file.
        """
        # copy the parameters into statics
        self.b = p
        self.k = j
        self.k0 = i
        if self.k <= self.k0 + 1:
            return self.b # --DEPARTURE--

        # With this line, strings of length 1 or 2 don't go through the
        # stemming process, although no mention is made of this in the
        # published algorithm. Remove the line to match the published
        # algorithm.

        self.step1ab()
        self.step1c()
        self.step2()
        self.step3()
        self.step4()
        self.step5()
        return self.b[self.k0:self.k+1]


# if __name__ == '__main__':
#     p = PorterStemmer()
#     if len(sys.argv) > 1:
#         for f in sys.argv[1:]:
#             infile = open(f, 'r')
#             while 1:
#                 output = ''
#                 word = ''
#                 line = infile.readline()
#                 if line == '':
#                     break
#                 for c in line:
#                     if c.isalpha():
#                         word += c.lower()
#                     else:
#                         if word:
#                             output += p.stem(word, 0,len(word)-1)
#                             word = ''
#                         output += c.lower()
#                 print output,
#             infile.close()

# %%
# dataDf['comment_text'] = dataDf['comment_text'].str.lower()
p = PorterStemmer()
p.stem(dataDf['comment_text'],0,len(dataDf)-1)
# Out:
# 0         explanation\nwhy the edits made under my usern...
# 1         d'aww! he matches this background colour i'm s...
# 2         hey man, i'm really not trying to edit war. it...
# 3         "\nmore\ni can't make any real suggestions on ...
# 4         you, sir, are my hero. any chance you remember...
# 5         "\n\ncongratulations from me as well, use the ...
# 6              cocksucker before you piss around on my work
# 7         your vandalism to the matt shirvington article...
# 8         sorry if the word 'nonsense' was offensive to ...
# 9         alignment on this subject and which are contra...
# 10        "\nfair use rationale for image:wonju.jpg\n\nt...
# 11        bbq \n\nbe a man and lets discuss it-maybe ove...
# 12        hey... what is it..\n@ | talk .\nwhat is it......
# 13        before you start throwing accusations and warn...
# 14        oh, and the girl above started her arguments w...
# 15        "\n\njuelz santanas age\n\nin 2002, juelz sant...
# 16        bye! \n\ndon't look, come or think of comming ...
# 17         redirect talk:voydan pop georgiev- chernodrinski
# 18        the mitsurugi point made no sense - why not ar...
# 19        don't mean to bother you \n\ni see that you're...
# 20        "\n\n regarding your recent edits \n\nonce aga...
# 21        "\ngood to know. about me, yeah, i'm studying ...
# 22        "\n\n snowflakes are not always symmetrical! \...
# 23        "\n\n the signpost: 24 september 2012 \n\n rea...
# 24        "\n\nre-considering 1st paragraph edit?\ni don...
# 25        radial symmetry \n\nseveral now extinct lineag...
# 26        there's no need to apologize. a wikipedia arti...
# 27        yes, because the mother of the child in the ca...
# 28        "\nok. but it will take a bit of work but i ca...
# 29        "== a barnstar for you! ==\n\n  the real life ...
#                                 ...
# 159541    your absurd edits \n\nyour absurd edits on gre...
# 159542    maybe he's got better things to do than spend ...
# 159543    scrap that, it does meet criteria and its gone...
# 159544                                  you could do worse.
# 159545    , 7 march 2011 (utc)\nare you also user:bmatts...
# 159546    "\n\nhey listen don't you ever!!!! delete my e...
# 159547                       thank you very, very much.  ·✆
# 159548                          talkback: 15 september 2012
# 159549                           2005 (utc)\n 06:35, 31 mar
# 159550    i agree/ on another note lil wayne is a talent...
# 159551    while about half the references are from byu-i...
# 159552    prague spring \n\ni think that prague spring d...
# 159553    i see this as having been merged; undoing one ...
# 159554    and i'm going to keep posting the stuff u dele...
# 159555    "\n\nhow come when you download that mp3 it's ...
# 159556    i'll be on irc, too, if you have a more specif...
# 159557    it is my opinion that that happens to be off-t...
# 159558    please stop removing content from wikipedia; i...
# 159559    image:barack-obama-mother.jpg listed for delet...
# 159560    "editing of article without consensus & remova...
# 159561    "\nno he did not, read it again (i would have ...
# 159562    "\n auto guides and the motoring press are not...
# 159563    "\nplease identify what part of blp applies be...
# 159564    catalan independentism is the social movement ...
# 159565    the numbers in parentheses are the additional ...
# 159566    ":::::and for the second time of asking, when ...
# 159567    you should be ashamed of yourself \n\nthat is ...
# 159568    spitzer \n\numm, theres no actual article for ...
# 159569    and it looks like it was actually you who put ...
# 159570    "\nand ... i really don't think you understand...
# Name: comment_text, Length: 159571, dtype: object

# %% [markdown]
# ### Basic data characteristics

# %%
def basic_characteristics(df):
    print('Number of data points: %d' %len(df))
    for klass in CLASSES:
        print('Number data points of type %s: %d' %(klass, len(df[df[klass]==1])))        
basic_characteristics(dataDf)
# Out:
# Number of data points: 159571
# Number data points of type toxic: 15294
# Number data points of type severe_toxic: 1595
# Number data points of type obscene: 8449
# Number data points of type threat: 478
# Number data points of type insult: 7877
# Number data points of type identity_hate: 1405

# %%
labels, counts = np.unique(dataDf[CLASSES].sum(axis=1), return_counts=True)
plt.bar(labels, counts, align='center')
plt.gca().set_title('Histogram of number of classes per datapoint')
plt.gca().set_xlabel('Number of classes per datapoint')
plt.gca().set_xticks(labels)
plt.show()

# %% [markdown]
# ### Embed text in vector space
#
# We use a simple count based vectorizer to embed the comment text into vector space in preparation for building classification models.

# %%
class CommentVectorizer:
    def __init__(self):
        self._vectorizers = []
        
    def get_count_vectorizer(self, max_features = 1000, ngram_range = (1, 2), 
                             stop_words = 'english', binary = True):
        """
        Initializes a count vectorizer with parameters set by the user and 
        returns an index in the internal vector array where the vectorizer
        has been placed. We dont want any external entity manipulating the
        vectorizer state directly.
        """
        self._vectorizers.append(CountVectorizer(max_features = max_features, 
                                                 ngram_range = ngram_range, 
                                                 stop_words = stop_words,
                                                 binary = binary))
        return len(self._vectorizers) - 1
    
    def get_tdidf_vectorizer(self, max_features = 5000, use_idf = True):
        self._vectorizers.append(TfidfVectorizer(max_df=0.7, max_features=max_features,
                                 min_df=2, stop_words='english',
                                 use_idf=use_idf))
        return len(self._vectorizers) - 1
    
    def doc2vec_fit_transform(self, sentences):
        """
        Method for building a doc2vec model. Unfortunately it does not follow the nice fit/transform
        pattern of the scikit models.
        """
        documents = map(lambda i: TaggedDocument(sentences[i].split(), [i]),
                        range(len(sentences)))
        model = Doc2Vec(documents, size=100, window=8, min_count=0, workers=8)
        return map(lambda x: model.docvecs[x], range(len(sentences)))
    
    def _exists(self, vectorizer):
        """
        Checks if the vectorizer index provided points to a valid vectorizer.
        """
        if vectorizer < 0 or len(self._vectorizers) <= vectorizer:
            raise Exception('Vectorizer index out of bound.')
            
        if self._vectorizers[vectorizer] == None:
            raise Exception('Vectorizer not initialized.')
            
        pass
        
    def fit(self, comments = [], vectorizer = -1):
        self._exists(vectorizer)
        self._vectorizers[vectorizer].fit(comments)
        
    def transform(self, comments, vectorizer):
        self._exists(vectorizer)
        return self._vectorizers[vectorizer].transform(comments)

# %%
# initialize a count vectorizer for this experiment    
commentVectorizer = CommentVectorizer()
vectorizer = commentVectorizer.get_tdidf_vectorizer()
commentVectorizer.fit(dataDf[TEXT_COLUMN], vectorizer)

# embed comments into vector space
commentVectors = commentVectorizer.transform(dataDf[TEXT_COLUMN], vectorizer)
# commentVectors = np.array(commentVectorizer.doc2vec_fit_transform(dataDf[TEXT_COLUMN]))

# %%
coords = TruncatedSVD(n_components=2).fit_transform(commentVectors)
plt.scatter(coords[:,0], coords[:,1], color='red' )
plt.title('Scatter plot of the comment vectors (reduced)')
# Out:
# Text(0.5,1,u'Scatter plot of the comment vectors (reduced)')

# %% [markdown]
# ### Create modeling and evaluation sets

# %%
# shuffle and split the dataset stratified by the number of classifications of a data point
# for balancing across resulting modeling and evaluation datasets
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=0)
for train_index, test_index in sss.split(np.zeros(len(dataDf)), dataDf[CLASSES].sum(axis=1)):
    pass

# modeling dataset
modeling_vectors = commentVectors[train_index]
modeling_classes = dataDf[CLASSES].loc[train_index]
print('Modeling data size: %d' %len(modeling_classes))
basic_characteristics(modeling_classes)

# evaluation dataset
evaluation_vectors = commentVectors[test_index]
evaluation_classes = dataDf[CLASSES].loc[test_index]
print('Evaluation data size: %d' %len(evaluation_classes))
basic_characteristics(evaluation_classes)
# Out:
# Modeling data size: 127656
# Number of data points: 127656
# Number data points of type toxic: 12219
# Number data points of type severe_toxic: 1280
# Number data points of type obscene: 6765
# Number data points of type threat: 386
# Number data points of type insult: 6314
# Number data points of type identity_hate: 1115
# Evaluation data size: 31915
# Number of data points: 31915
# Number data points of type toxic: 3075
# Number data points of type severe_toxic: 315
# Number data points of type obscene: 1684
# Number data points of type threat: 92
# Number data points of type insult: 1563
# Number data points of type identity_hate: 290

# %% [markdown]
# ### Build classification model

# %%
X = modeling_vectors
y = modeling_classes


rfc = RandomForestClassifier(n_jobs=-1,max_features= 'sqrt' ,n_estimators=50, oob_score = True) 

param_grid = { 
    'n_estimators': [5, 10],
    'max_features': ['auto', 'sqrt', 'log2']
}

CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X, y)
print CV_rfc.best_params_

# %%
SVC(C=1.0, cache_size=50, class_weight='balanced', decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf', max_iter=-1, probability=True, random_state=1, shrinking=True, tol=0.001)
RandomForestClassifier(n_estimators = 150, class_weight = 'balanced', n_jobs=-1, criterion="entropy")

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
 
X = modeling_vectors
Y = modeling_classes["toxic"]
names = commentVectors[train_index]
 
#use linear regression as the model
lr = LinearRegression()
#rank all features, i.e continue the elimination until the last one
rfe = RFE(lr, n_features_to_select=1)
rfe.fit(X,Y)
 
print "Features sorted by their rank:"
print sorted(zip(map(lambda x: round(x, 4), rfe.ranking_), names))
# Out:
# Features sorted by their rank:
# [(1.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (2.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (3.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (5.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (6.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (7.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (8.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (9.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (10.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (11.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (12.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (13.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (14.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (15.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (16.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (17.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (18.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (19.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 28 stored elements in Compressed Sparse Row format>), (20.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (21.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (22.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 24 stored elements in Compressed Sparse Row format>), (23.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (24.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (25.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (26.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 28 stored elements in Compressed Sparse Row format>), (27.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 53 stored elements in Compressed Sparse Row format>), (28.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (29.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (30.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (31.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (32.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (33.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 34 stored elements in Compressed Sparse Row format>), (34.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (35.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (36.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (37.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (38.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (39.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (40.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 28 stored elements in Compressed Sparse Row format>), (41.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (42.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (43.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (44.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (45.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 47 stored elements in Compressed Sparse Row format>), (46.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 59 stored elements in Compressed Sparse Row format>), (47.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (48.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (49.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (50.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (51.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 32 stored elements in Compressed Sparse Row format>), (52.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (53.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 35 stored elements in Compressed Sparse Row format>), (54.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (55.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (56.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (57.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (58.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (59.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (60.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (61.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (62.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 34 stored elements in Compressed Sparse Row format>), (63.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 178 stored elements in Compressed Sparse Row format>), (64.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (65.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (66.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (67.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (68.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (69.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (70.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (71.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (72.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (73.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (74.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 36 stored elements in Compressed Sparse Row format>), (75.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (76.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 38 stored elements in Compressed Sparse Row format>), (77.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (78.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (79.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 37 stored elements in Compressed Sparse Row format>), (80.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (81.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (82.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (83.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (84.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (85.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (86.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 58 stored elements in Compressed Sparse Row format>), (87.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (88.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 114 stored elements in Compressed Sparse Row format>), (89.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (90.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (91.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (92.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (93.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (94.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 32 stored elements in Compressed Sparse Row format>), (95.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (96.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (97.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (98.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (99.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (100.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (101.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 120 stored elements in Compressed Sparse Row format>), (102.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (103.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (104.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (105.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (106.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (107.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (108.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (109.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (110.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 52 stored elements in Compressed Sparse Row format>), (111.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 120 stored elements in Compressed Sparse Row format>), (112.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 41 stored elements in Compressed Sparse Row format>), (113.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 29 stored elements in Compressed Sparse Row format>), (114.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 37 stored elements in Compressed Sparse Row format>), (115.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 37 stored elements in Compressed Sparse Row format>), (116.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (117.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (118.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (119.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (120.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (121.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (122.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (123.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (124.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (125.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (126.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 50 stored elements in Compressed Sparse Row format>), (127.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (128.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 33 stored elements in Compressed Sparse Row format>), (129.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (130.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (131.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (132.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (133.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (134.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (135.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (136.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (137.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 55 stored elements in Compressed Sparse Row format>), (138.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (139.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (140.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (141.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (142.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 50 stored elements in Compressed Sparse Row format>), (143.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (144.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (145.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (146.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 58 stored elements in Compressed Sparse Row format>), (147.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (148.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (149.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (150.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 38 stored elements in Compressed Sparse Row format>), (151.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (152.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (153.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (154.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (155.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (156.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (157.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (158.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (159.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 32 stored elements in Compressed Sparse Row format>), (160.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (161.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 63 stored elements in Compressed Sparse Row format>), (162.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (163.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 32 stored elements in Compressed Sparse Row format>), (164.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (165.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 24 stored elements in Compressed Sparse Row format>), (166.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 37 stored elements in Compressed Sparse Row format>), (167.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (168.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (169.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (170.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (171.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (172.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (173.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (174.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (175.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (176.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 40 stored elements in Compressed Sparse Row format>), (177.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (178.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 54 stored elements in Compressed Sparse Row format>), (179.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 35 stored elements in Compressed Sparse Row format>), (180.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (181.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (182.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (183.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (184.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (185.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (186.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (187.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 42 stored elements in Compressed Sparse Row format>), (188.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 62 stored elements in Compressed Sparse Row format>), (189.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (190.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 44 stored elements in Compressed Sparse Row format>), (191.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (192.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 51 stored elements in Compressed Sparse Row format>), (193.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (194.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (195.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (196.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (197.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (198.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (199.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (200.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>), (201.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (202.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (203.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (204.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (205.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (206.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 24 stored elements in Compressed Sparse Row format>), (207.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (208.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (209.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (210.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (211.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 41 stored elements in Compressed Sparse Row format>), (212.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (213.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (214.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 57 stored elements in Compressed Sparse Row format>), (215.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (216.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (217.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (218.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (219.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (220.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (221.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (222.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (223.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 140 stored elements in Compressed Sparse Row format>), (224.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (225.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 35 stored elements in Compressed Sparse Row format>), (226.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (227.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (228.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 37 stored elements in Compressed Sparse Row format>), (229.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 24 stored elements in Compressed Sparse Row format>), (230.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (231.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (232.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (233.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (234.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 115 stored elements in Compressed Sparse Row format>), (235.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (236.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (237.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (238.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (239.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (240.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (241.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (242.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (243.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (244.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 30 stored elements in Compressed Sparse Row format>), (245.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (246.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (247.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (248.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (249.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>), (250.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 76 stored elements in Compressed Sparse Row format>), (251.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (252.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 64 stored elements in Compressed Sparse Row format>), (253.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (254.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (255.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (256.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (257.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (258.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (259.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (260.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (261.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (262.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (263.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (264.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (265.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 63 stored elements in Compressed Sparse Row format>), (266.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (267.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (268.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (269.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (270.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 31 stored elements in Compressed Sparse Row format>), (271.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (272.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (273.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (274.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (275.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (276.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (277.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (278.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (279.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (280.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (281.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (282.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (283.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (284.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (285.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 49 stored elements in Compressed Sparse Row format>), (286.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (287.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (288.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 48 stored elements in Compressed Sparse Row format>), (289.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (290.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (291.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 45 stored elements in Compressed Sparse Row format>), (292.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (293.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (294.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (295.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (296.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (297.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (298.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (299.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (300.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (301.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 40 stored elements in Compressed Sparse Row format>), (302.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (303.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (304.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (305.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (306.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (307.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (308.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (309.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>), (310.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (311.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (312.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (313.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (314.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 42 stored elements in Compressed Sparse Row format>), (315.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (316.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (317.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 24 stored elements in Compressed Sparse Row format>), (318.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>), (319.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 50 stored elements in Compressed Sparse Row format>), (320.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 28 stored elements in Compressed Sparse Row format>), (321.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (322.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (323.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (324.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (325.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (326.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (327.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (328.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (329.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (330.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (331.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (332.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (333.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (334.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (335.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (336.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (337.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (338.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (339.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 13 stored elements in Compressed Sparse Row format>), (340.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 46 stored elements in Compressed Sparse Row format>), (341.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (342.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 0 stored elements in Compressed Sparse Row format>), (343.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 34 stored elements in Compressed Sparse Row format>), (344.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (345.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (346.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (347.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (348.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (349.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (350.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (351.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (352.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (353.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (354.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 87 stored elements in Compressed Sparse Row format>), (355.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (356.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (357.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (358.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (359.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (360.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 49 stored elements in Compressed Sparse Row format>), (361.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 51 stored elements in Compressed Sparse Row format>), (362.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (363.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 43 stored elements in Compressed Sparse Row format>), (364.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (365.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (366.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 20 stored elements in Compressed Sparse Row format>), (367.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>), (368.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (369.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (370.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (371.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (372.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (373.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (374.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 33 stored elements in Compressed Sparse Row format>), (375.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (376.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (377.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (378.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (379.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (380.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 76 stored elements in Compressed Sparse Row format>), (381.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 47 stored elements in Compressed Sparse Row format>), (382.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (383.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (384.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (385.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 41 stored elements in Compressed Sparse Row format>), (386.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (387.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (388.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (389.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (390.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (391.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (392.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# ...
# 	with 15 stored elements in Compressed Sparse Row format>), (4873.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4874.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (4875.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (4876.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4877.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (4878.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (4879.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (4880.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 117 stored elements in Compressed Sparse Row format>), (4881.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (4882.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4883.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (4884.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 39 stored elements in Compressed Sparse Row format>), (4885.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (4886.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>), (4887.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4888.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4889.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (4890.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4891.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4892.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (4893.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4894.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 116 stored elements in Compressed Sparse Row format>), (4895.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (4896.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (4897.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 49 stored elements in Compressed Sparse Row format>), (4898.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (4899.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4900.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4901.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (4902.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (4903.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 86 stored elements in Compressed Sparse Row format>), (4904.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (4905.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 29 stored elements in Compressed Sparse Row format>), (4906.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 28 stored elements in Compressed Sparse Row format>), (4907.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4908.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (4909.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 24 stored elements in Compressed Sparse Row format>), (4910.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (4911.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (4912.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (4913.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4914.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 48 stored elements in Compressed Sparse Row format>), (4915.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4916.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 61 stored elements in Compressed Sparse Row format>), (4917.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (4918.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4919.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (4920.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (4921.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>), (4922.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4923.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4924.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4925.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (4926.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4927.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (4928.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (4929.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 22 stored elements in Compressed Sparse Row format>), (4930.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4931.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (4932.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 79 stored elements in Compressed Sparse Row format>), (4933.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4934.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 27 stored elements in Compressed Sparse Row format>), (4935.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (4936.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (4937.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 42 stored elements in Compressed Sparse Row format>), (4938.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (4939.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (4940.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4941.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (4942.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 36 stored elements in Compressed Sparse Row format>), (4943.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (4944.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4945.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>), (4946.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>), (4947.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 21 stored elements in Compressed Sparse Row format>), (4948.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 30 stored elements in Compressed Sparse Row format>), (4949.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4950.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 16 stored elements in Compressed Sparse Row format>), (4951.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4952.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (4953.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 219 stored elements in Compressed Sparse Row format>), (4954.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4955.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4956.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 23 stored elements in Compressed Sparse Row format>), (4957.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (4958.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (4959.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (4960.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 42 stored elements in Compressed Sparse Row format>), (4961.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (4962.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (4963.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 18 stored elements in Compressed Sparse Row format>), (4964.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4965.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 36 stored elements in Compressed Sparse Row format>), (4966.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (4967.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10 stored elements in Compressed Sparse Row format>), (4968.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4969.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (4970.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4971.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 25 stored elements in Compressed Sparse Row format>), (4972.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (4973.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 34 stored elements in Compressed Sparse Row format>), (4974.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 28 stored elements in Compressed Sparse Row format>), (4975.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4976.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4977.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4978.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 17 stored elements in Compressed Sparse Row format>), (4979.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4980.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (4981.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4982.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>), (4983.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>), (4984.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 6 stored elements in Compressed Sparse Row format>), (4985.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 157 stored elements in Compressed Sparse Row format>), (4986.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>), (4987.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (4988.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 26 stored elements in Compressed Sparse Row format>), (4989.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 62 stored elements in Compressed Sparse Row format>), (4990.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 4 stored elements in Compressed Sparse Row format>), (4991.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>), (4992.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 46 stored elements in Compressed Sparse Row format>), (4993.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12 stored elements in Compressed Sparse Row format>), (4994.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 39 stored elements in Compressed Sparse Row format>), (4995.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (4996.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 40 stored elements in Compressed Sparse Row format>), (4997.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 14 stored elements in Compressed Sparse Row format>), (4998.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>), (4999.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 7 stored elements in Compressed Sparse Row format>), (5000.0, <1x5000 sparse matrix of type '<type 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>)]

# %%
from sklearn.pipeline import Pipeline
from sklearn.multioutput import MultiOutputClassifier

class ExtendedMultiOutputClassifier(MultiOutputClassifier):
    def transform(self, X):
        """
        Add a transform method to the classifier because it is mandatory for steps of a pipeline
        to provide fit and transform methods.
        """
        _o = self.predict_proba(X)
        return np.concatenate(_o, axis=1)

moc = ExtendedMultiOutputClassifier(SVC(C=1e-3, cache_size=10, decision_function_shape='ovo', kernel='linear', max_iter=7000, probability=True, random_state=1, tol=0.001))
nnc = MLPClassifier(solver='sgd', activation='logistic', learning_rate='adaptive', momentum=0.9, alpha=1e-2, hidden_layer_sizes=(150, 150), random_state=1, tol=1e-15)
# specify the order in which pipeline should execute the classifiers/estimators
clf = Pipeline([('moc_rf', moc), ('nnc', nnc)])
# fit all the transforms one after the other and transform the data, then fit the transformed data using the final estimator.
clf.fit(modeling_vectors, modeling_classes)
# rudimentary test
predictions = clf.predict_proba(modeling_vectors)

# calculate MSE (mean squared error). note np.dot on full matrix gives 
# memmory error hence the slow work around
d = predictions - modeling_classes
sq_difs = map(lambda x: np.dot(x, x.T), d.as_matrix())
print('MSE: %f' %(np.sum(sq_difs) * 1.0 / len(d)))

# %% [markdown]
# ### Evaluation

# %%
predictions = clf.predict_proba(evaluation_vectors)

# MSE
d = predictions - evaluation_classes
sq_difs = map(lambda x: np.dot(x, x.T), d.as_matrix())
print('MSE: %f' %(np.sum(sq_difs) * 1.0 / len(d)))

# %% [markdown]
# ### Read in test dataset

# %%
testdf = pd.read_csv('C:/Users/sharm/Desktop/Dat5Melb/Final_Project/Datasets/test1/test.csv')
testdf.id = testdf.id.astype(basestring)
testdf.head()

# %%
testdf.info()

# %% [markdown]
# ### Embded test dataset

# %%
# embed comments into vector space
testcommentVectors = commentVectorizer.transform(testdf[TEXT_COLUMN], vectorizer)
testcommentVectors

# %% [markdown]
# ### Predict final probabilities

# %%
testpredictions = clf.predict_proba(testcommentVectors)
testpdf = pd.DataFrame(data=testpredictions)

# %%
submissiondf = testpdf.join(testdf['id'], how='left')
submissiondf = submissiondf[['id',0,1,2,3,4,5]]
submissiondf.columns = ["id", "toxic", "severe_toxic", "obscene", "threat","insult", "identity_hate"]
submissiondf.head()

# %%
# submissiondf.to_csv('submission.csv', index=False)

def manual_write(submissiondf,filename):
    of = file(filename, 'w')
    of.write('%s\n' %','.join(submissiondf.columns))
    for idx in range(len(submissiondf)):
        of.write('%s\n' %','.join(map(str, submissiondf.iloc[idx].tolist())))
    of.close()

manual_write(submissiondf, 'submission2.csv')

# %%
submissiondf.info()
